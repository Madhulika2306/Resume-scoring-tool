# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
i=int(input("enter the num"))
k=int(input("upto"))
for j in range(1,k+1):
    l=i*j
    print(i, "x",j, "=",l)
# Out:
# enter the num 4
# upto 10
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
def guess_number(low,high):
    if low>high:
        print("number is found")
        return
    mid=(high+low)//2
    print("is the number",mid,"yes/no")
    ans=input()
    if ans=="yes":
        print("number found",mid)
    elif ans=="no":
        print("ans is smaller than ",mid,"yes/no")
        ans=input()
        if ans=="yes":
            print("number found",mid)
        elif ans=="no":
            print("ans is smaller than ",mid,"yes/no")
            ans=input()
            if ans=="yes":
                guess_number(low,mid-1)
            elif ans=="no":
                guess_number(mid+1,high)
            else:
                print("invalid input")
                guess_number(low,high)
        else:
            print("invalid input")
            huess_number(low,high)
guess_number(1,100)
# Out:
# is the number 50 yes/no
#  no
# ans is smaller than  50 yes/no
#  yes
# number found 50
